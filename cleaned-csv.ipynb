# %%
import pandas as pd

# %%
all="allDogDescriptions.csv"

# %%
all_dog= pd.read_csv(all)
all_dog
# Out:
#        index        id org_id  \
# 0          0  46042150  NV163
# 1          1  46042002  NV163
# 2          2  46040898   NV99
# 3          3  46039877  NV202
# 4          4  46039306  NV184
# ...      ...       ...    ...
# 58175  58175  44605893   WY20
# 58176  58176  44457061   WY24
# 58177  58177  42865848   WY20
# 58178  58178  42734734   WY24
# 58179  58179  42663515   WY24
#
#                                                      url type.x species  \
# 0      https://www.petfinder.com/dog/harley-46042150/...    Dog     Dog
# 1      https://www.petfinder.com/dog/biggie-46042002/...    Dog     Dog
# 2      https://www.petfinder.com/dog/ziggy-46040898/n...    Dog     Dog
# 3      https://www.petfinder.com/dog/gypsy-46039877/n...    Dog     Dog
# 4      https://www.petfinder.com/dog/theo-46039306/nv...    Dog     Dog
# ...                                                  ...    ...     ...
# 58175  https://www.petfinder.com/dog/tren-44605893/wy...    Dog     Dog
# ...

# %%
all_dogs=all_dog.iloc[:,[1,3,5,6,8,10,13,14,15,16,17,18,21,25,28,29,30, 35]]
all_dogs
# Out:
#              id                                                url species  \
# 0      46042150  https://www.petfinder.com/dog/harley-46042150/...     Dog
# 1      46042002  https://www.petfinder.com/dog/biggie-46042002/...     Dog
# 2      46040898  https://www.petfinder.com/dog/ziggy-46040898/n...     Dog
# 3      46039877  https://www.petfinder.com/dog/gypsy-46039877/n...     Dog
# 4      46039306  https://www.petfinder.com/dog/theo-46039306/nv...     Dog
# ...         ...                                                ...     ...
# 58175  44605893  https://www.petfinder.com/dog/tren-44605893/wy...     Dog
# 58176  44457061  https://www.petfinder.com/dog/harley-44457061/...     Dog
# 58177  42865848  https://www.petfinder.com/dog/echo-42865848/wy...     Dog
# 58178  42734734  https://www.petfinder.com/dog/simon-42734734/w...     Dog
# 58179  42663515  https://www.petfinder.com/dog/romeo-42663515/w...     Dog
#
#                         breed_primary  breed_mixed  \
# ...

# %%
state_dogs = all_dogs.loc[
(all_dogs['contact_state'] == 'NJ')]

state_dogs
# Out:
#              id                                                url species  \
# 8634   46038097  https://www.petfinder.com/dog/lola-46038097/nj...     Dog
# 8635   46038089  https://www.petfinder.com/dog/stella-46038089/...     Dog
# 8647   46036860  https://www.petfinder.com/dog/lady-bugette-460...     Dog
# 8653   46035773  https://www.petfinder.com/dog/coop-46035773/nj...     Dog
# 8654   46036827  https://www.petfinder.com/dog/conrad-46036827/...     Dog
# ...         ...                                                ...     ...
# 44810  14262994  https://www.petfinder.com/dog/fosters-needed-1...     Dog
# 44811  13970485  https://www.petfinder.com/dog/maverick-1397048...     Dog
# 44812  13144912  https://www.petfinder.com/dog/miley-13144912/n...     Dog
# 44813  12134429  https://www.petfinder.com/dog/sweet-seniors-12...     Dog
# 44814   7755992  https://www.petfinder.com/dog/in-loving-memory...     Dog
#
# ...

# %%
state_dogs=state_dogs.dropna(axis=0)

# %%
state_dog=pd.DataFrame(state_dogs)
state_dog
# Out:
#              id                                                url species  \
# 8634   46038097  https://www.petfinder.com/dog/lola-46038097/nj...     Dog
# 8635   46038089  https://www.petfinder.com/dog/stella-46038089/...     Dog
# 8647   46036860  https://www.petfinder.com/dog/lady-bugette-460...     Dog
# 8688   46033538  https://www.petfinder.com/dog/barbe-46033538/n...     Dog
# 8693   46033360  https://www.petfinder.com/dog/rocket-46033360/...     Dog
# ...         ...                                                ...     ...
# 44808  15452638  https://www.petfinder.com/dog/dexter-15452638/...     Dog
# 44809  14794126  https://www.petfinder.com/dog/baby-blue-147941...     Dog
# 44811  13970485  https://www.petfinder.com/dog/maverick-1397048...     Dog
# 44812  13144912  https://www.petfinder.com/dog/miley-13144912/n...     Dog
# 44813  12134429  https://www.petfinder.com/dog/sweet-seniors-12...     Dog
#
#                         breed_primary  breed_mixed  \
# ...

# %%
state_dog.to_csv("state_dog.csv", index=False)
